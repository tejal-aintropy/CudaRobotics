# %% [markdown]
# <a href="https://colab.research.google.com/github/tejal-aintropy/CudaRobotics/blob/master/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

pd.pandas.set_option('display.max_columns',None)

# %%
dataset = pd.read_csv('/content/platinum_video_file_profiling - Video Profiles.csv')

print(dataset.shape)
# Out:
# (204, 18)

# %%
features_with_na = [features for features in dataset.columns if dataset[features].isnull().sum()>1]
for feature in features_with_na:
  print(feature,np.round(dataset[feature].isnull().mean(),4)),
# Out:
# Platinum Video File Profiling (200 videos profiled) 0.0147
# Unnamed: 1 0.0147
# Unnamed: 2 0.0147
# Unnamed: 3 0.0098
# Unnamed: 4 0.0147
# Unnamed: 5 0.0147
# Unnamed: 7 0.0147
# Unnamed: 8 0.0147
# Unnamed: 9 0.0147
# Unnamed: 10 0.0147
# Unnamed: 11 0.0147
# Unnamed: 12 0.0147
# Unnamed: 13 0.2108
# Unnamed: 14 0.2108
# Unnamed: 15 0.2108
# Unnamed: 16 0.0147
# Unnamed: 17 0.9951
